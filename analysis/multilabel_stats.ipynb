# %%
import json
from glob import glob
import numpy as np
import matplotlib.pyplot as plt
from itertools import groupby
import pandas as pd
from collections import Counter

# %%
docs = json.load(open("../data/dev_subtask1.json"))

# %%
np.sum([len(ann["labels"]) > 2 for lang in docs.values() for dlang in lang.values() for ann in dlang["annotations"]])

# %%
2 / 604

# %%
len([len(ann["labels"]) == 1 for lang in docs.values() for dlang in lang.values() for ann in dlang["annotations"]])

# %%
doc_names = list({d.replace(".txt", "") for lang in docs.values() for d in lang.keys()})

# %%
sum([len(open(f"../kg/{name}.nq").readlines()) for name in doc_names])

# %%
frames_ann = [json.load(open(f"../data/frames/{dname}.json")) for dname in doc_names]

# %%
#Counter([x["name"] for fann in frames_ann for x in fann["frames"]])

# %%
np.mean([len(fann["frames"]) for fann in frames_ann])

# %%
frames_ann_lang = {lang: list(fanns) for lang, fanns in groupby(sorted(frames_ann, key=lambda f: f["language"]), key=lambda f: f["language"])}

# %%
#frames_ann_lang

# %%
for l, anns in frames_ann_lang.items():
    plt.hist(sorted([len(a["frames"]) for a in anns]), bins=5, alpha=0.5, histtype="step", )

# %%
num_frames = [len(fann["frames"]) for fann in frames_ann]

plt.plot(sorted(num_frames))
